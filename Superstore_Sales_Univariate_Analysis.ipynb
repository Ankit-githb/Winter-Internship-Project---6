# %% [markdown]
# <a href="https://colab.research.google.com/github/Ankit-githb/Winter-Internship-Project---6/blob/main/Superstore_Sales_Univariate_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Understand Dataset

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load the dataset (replace 'path/to/your/IndianCarsDataset.csv' with the actual file path)
df = pd.read_csv('https://raw.githubusercontent.com/Ankit-githb/Winter-Internship-Project---6/main/train.csv')

# %%
# Display the First Few Rows
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
# Get Information About the Dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     9800 non-null   object
#  3   Ship Date      9800 non-null   object
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal Code    9789 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub-Category   9800 non-null   object
#  16  Product Name   9800 non-null   object
# ...

# %%
# Summary Statistics
df.describe()
# Out:
#             Row ID   Postal Code         Sales
# count  9800.000000   9789.000000   9800.000000
# mean   4900.500000  55273.322403    230.769059
# std    2829.160653  32041.223413    626.651875
# min       1.000000   1040.000000      0.444000
# 25%    2450.750000  23223.000000     17.248000
# 50%    4900.500000  58103.000000     54.490000
# 75%    7350.250000  90008.000000    210.605000
# max    9800.000000  99301.000000  22638.480000

# %%
# Display basic information about the DataFrame
print("Number of rows:", df.shape[0])
print("Number of columns:", df.shape[1])
# Out:
# Number of rows: 9800
# Number of columns: 18

# %%
# Display the first few rows of the DataFrame to get a sense of the data
print("\nFirst few rows of the DataFrame:")
print(df.head())
# Out:
# First few rows of the DataFrame:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %% [markdown]
# 2. Data Cleaning

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load the dataset (replace 'path/to/your/IndianCarsDataset.csv' with the actual file path)
df = pd.read_csv('https://raw.githubusercontent.com/Ankit-githb/Winter-Internship-Project---6/main/train.csv')

# %%
# Display the number of missing values in each column
missing_values = df.isnull().sum()
print("Missing values in each column:\n", missing_values)
# Out:
# Missing values in each column:
#  Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country           0
# City              0
# State             0
# Postal Code      11
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# dtype: int64

# %%
# Drop rows with missing values in any column
df = df.dropna()

# %%
# Replace missing values in 'your_column' with the mean of that column
if 'your_column' in df.columns:
    df['your_column'] = df['your_column'].fillna(df['your_column'].mean())

# %%
# Display summary statistics
summary_stats = df.describe()
print("Summary Statistics:\n", summary_stats)
# Out:
# Summary Statistics:
#              Row ID   Postal Code         Sales
# count  9789.000000   9789.000000   9789.000000
# mean   4896.705588  55273.322403    230.116193
# std    2827.486899  32041.223413    625.302079
# min       1.000000   1040.000000      0.444000
# 25%    2449.000000  23223.000000     17.248000
# 50%    4896.000000  58103.000000     54.384000
# 75%    7344.000000  90008.000000    210.392000
# max    9800.000000  99301.000000  22638.480000

# %%
df['New_Column'] = [1] * len(df)
sns.histplot(df['New_Column'])
plt.title('Distribution of New_Column')
plt.show()

# %%
# Choose and implement a strategy (e.g., replace with mean)
df.fillna(df.mean(), inplace=True)

# Visual inspection (you may need to install additional libraries)
sns.boxplot(data=df)  # Example of a boxplot for outlier detection
# Out:
# <ipython-input-17-9434e753a681>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.fillna(df.mean(), inplace=True)
# <Axes: >

# %% [markdown]
# 3. Data Types

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load the dataset (replace 'path/to/your/IndianCarsDataset.csv' with the actual file path)
df = pd.read_csv('https://raw.githubusercontent.com/Ankit-githb/Winter-Internship-Project---6/main/train.csv')

# %%
# Check data types of each column
data_types = df.dtypes

# Display data types
print("Data Types:")
print(data_types)
# Out:
# Data Types:
# Row ID             int64
# Order ID          object
# Order Date        object
# Ship Date         object
# Ship Mode         object
# Customer ID       object
# Customer Name     object
# Segment           object
# Country           object
# City              object
# State             object
# Postal Code      float64
# Region            object
# Product ID        object
# Category          object
# Sub-Category      object
# Product Name      object
# Sales            float64
# dtype: object

# %%
# Perform analysis, e.g., calculate summary statistics
summary_stats = df.describe()

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales
# count  9800.000000   9789.000000   9800.000000
# mean   4900.500000  55273.322403    230.769059
# std    2829.160653  32041.223413    626.651875
# min       1.000000   1040.000000      0.444000
# 25%    2450.750000  23223.000000     17.248000
# 50%    4900.500000  58103.000000     54.490000
# 75%    7350.250000  90008.000000    210.605000
# max    9800.000000  99301.000000  22638.480000

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales'],
#       dtype='object')

# %%
df['column1'] = pd.to_numeric(df['Order ID'], errors='coerce')

# %%
 #Example: Convert 'date_column' to datetime
df['date_column'] = pd.to_datetime(df['Order Date'], errors='coerce')
df = df.rename(columns={'Order Date': 'date_column'})
# Out:
# <ipython-input-25-3bec0015522c>:2: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['date_column'] = pd.to_datetime(df['Order Date'], errors='coerce')

# %%
# Verify changes
# Display the first few rows of the DataFrame after changes
df.head()
# Out:
#    Row ID        Order ID date_column   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
# Check data types again after conversion
data_types_after = df.dtypes
print("\nData Types After Conversion:")
print(data_types_after)
# Out:
# Data Types After Conversion:
# Row ID                    int64
# Order ID                 object
# date_column              object
# Ship Date                object
# Ship Mode                object
# Customer ID              object
# Customer Name            object
# Segment                  object
# Country                  object
# City                     object
# State                    object
# Postal Code             float64
# Region                   object
# Product ID               object
# Category                 object
# Sub-Category             object
# Product Name             object
# Sales                   float64
# column1                 float64
# date_column      datetime64[ns]
# dtype: object

# %% [markdown]
# 4. Descriptive Statistics

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load the dataset (replace 'path/to/your/IndianCarsDataset.csv' with the actual file path)
df = pd.read_csv('https://raw.githubusercontent.com/Ankit-githb/Winter-Internship-Project---6/main/train.csv')

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales
# count  9800.000000   9789.000000   9800.000000
# mean   4900.500000  55273.322403    230.769059
# std    2829.160653  32041.223413    626.651875
# min       1.000000   1040.000000      0.444000
# 25%    2450.750000  23223.000000     17.248000
# 50%    4900.500000  58103.000000     54.490000
# 75%    7350.250000  90008.000000    210.605000
# max    9800.000000  99301.000000  22638.480000

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales'],
#       dtype='object')

# %%
data = {'Sales': [100, 150, 200, 250, 300],
        'Quantity': [10, 15, 20, 25, 30]}
df = pd.DataFrame(data)

# %%
mean_sales = df['Sales'].mean()
mean_quantity = df['Quantity'].mean()

print(f'Mean Sales: {mean_sales}')
print(f'Mean Quantity: {mean_quantity}')
# Out:
# Mean Sales: 200.0
# Mean Quantity: 20.0

# %%
median_sales = df['Sales'].median()
median_quantity = df['Quantity'].median()

print(f'Median Sales: {median_sales}')
print(f'Median Quantity: {median_quantity}')
# Out:
# Median Sales: 200.0
# Median Quantity: 20.0

# %%
mode_sales = df['Sales'].mode()
mode_quantity = df['Quantity'].mode()

print(f'Mode Sales: {mode_sales.values}')  # In case there are multiple modes
print(f'Mode Quantity: {mode_quantity.values}')
# Out:
# Mode Sales: [100 150 200 250 300]
# Mode Quantity: [10 15 20 25 30]

# %%
range_sales = df['Sales'].max() - df['Sales'].min()
range_quantity = df['Quantity'].max() - df['Quantity'].min()

print(f'Range Sales: {range_sales}')
print(f'Range Quantity: {range_quantity}')
# Out:
# Range Sales: 200
# Range Quantity: 20

# %%
std_sales = df['Sales'].std()
std_quantity = df['Quantity'].std()

print(f'Standard Deviation Sales: {std_sales}')
print(f'Standard Deviation Quantity: {std_quantity}')
# Out:
# Standard Deviation Sales: 79.05694150420949
# Standard Deviation Quantity: 7.905694150420948

# %% [markdown]
# 5. Histograms

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load the dataset (replace 'path/to/your/IndianCarsDataset.csv' with the actual file path)
df = pd.read_csv('https://raw.githubusercontent.com/Ankit-githb/Winter-Internship-Project---6/main/train.csv')

# %%
# data
data = {'column1': [1, 3, 5, 7, 9, 2, 4, 6, 8, 10],
        'column2': [2, 4, 6, 8, 10, 1, 3, 5, 7, 9]}

df = pd.DataFrame(data)

# Set up subplots for each histogram
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))

# Plot histograms using Matplotlib and Seaborn
sns.histplot(df['column1'], bins=10, kde=False, ax=axes[0])
axes[0].set_title('Histogram for column1')
axes[0].set_xlabel('Values')
axes[0].set_ylabel('Frequency')

sns.histplot(df['column2'], bins=10, kde=False, ax=axes[1])
axes[1].set_title('Histogram for column2')
axes[1].set_xlabel('Values')
axes[1].set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# 6. Time Series Plots

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load the dataset (replace 'path/to/your/IndianCarsDataset.csv' with the actual file path)
df = pd.read_csv('https://raw.githubusercontent.com/Ankit-githb/Winter-Internship-Project---6/main/train.csv')

# %%
# view the shape of the dataframe
df.shape
# Out:
# (9800, 18)

# %%
# view the first 5 rows of dataset
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
# view summary of dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     9800 non-null   object
#  3   Ship Date      9800 non-null   object
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal Code    9789 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub-Category   9800 non-null   object
#  16  Product Name   9800 non-null   object
# ...

# %%
# convert the lastUpdated column into datetime format
# check if the column exists before converting it to datetime format
if 'LastUpdated' in df.columns:
    df['LastUpdated'] = pd.to_datetime(df['LastUpdated'])

# %%
# again view the summary of dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     9800 non-null   object
#  3   Ship Date      9800 non-null   object
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal Code    9789 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub-Category   9800 non-null   object
#  16  Product Name   9800 non-null   object
# ...

# %%
df['LastUpdated'] = np.random.choice(pd.date_range('2023-01-01', '2023-03-31'), size=df.shape[0])

df.dropna(subset=['Order ID', 'Customer ID'], inplace=True)

# %%
df['Date'] = df['LastUpdated'].dt.date

df['Time'] = df['LastUpdated'].dt.time

# %%
# again view the first ten rows of dataset
df.head(10)
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 5       6  CA-2015-115812  09/06/2015  14/06/2015  Standard Class    BH-11710
# 6       7  CA-2015-115812  09/06/2015  14/06/2015  Standard Class    BH-11710
# 7       8  CA-2015-115812  09/06/2015  14/06/2015  Standard Class    BH-11710
# 8       9  CA-2015-115812  09/06/2015  14/06/2015  Standard Class    BH-11710
# 9      10  CA-2015-115812  09/06/2015  14/06/2015  Standard Class    BH-11710
#
#      Customer Name    Segment        Country             City  ...  \
# ...

# %%
# remove columns

cols = ['Oder Id', 'Capacity', 'LastUpdated']

# check if columns exist in dataframe
if all(col in df.columns for col in cols):
    # drop columns if they exist
    df.drop(cols, axis=1, inplace=True)

# %%
# check the data types of the columns
df.dtypes
# Out:
# Row ID                    int64
# Order ID                 object
# Order Date               object
# Ship Date                object
# Ship Mode                object
# Customer ID              object
# Customer Name            object
# Segment                  object
# Country                  object
# City                     object
# State                    object
# Postal Code             float64
# Region                   object
# Product ID               object
# Category                 object
# Sub-Category             object
# Product Name             object
# Sales                   float64
# LastUpdated      datetime64[ns]
# Date                     object
# Time                     object
# dtype: object

# %%
# convert the data type of Date column
df['Date']=pd.to_datetime(df['Date'])

# %%
# again check the data type of df dataframe
df.dtypes
# Out:
# Row ID                    int64
# Order ID                 object
# Order Date               object
# Ship Date                object
# Ship Mode                object
# Customer ID              object
# Customer Name            object
# Segment                  object
# Country                  object
# City                     object
# State                    object
# Postal Code             float64
# Region                   object
# Product ID               object
# Category                 object
# Sub-Category             object
# Product Name             object
# Sales                   float64
# LastUpdated      datetime64[ns]
# Date             datetime64[ns]
# Time                     object
# dtype: object

# %%
# add the Date column to the dataframe
df['Date'] = pd.to_datetime(df['Order Date'])

# set the index of the dataframe
df.set_index('Date', inplace=True)
# Out:
# <ipython-input-56-dba0656c8a2b>:2: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['Date'] = pd.to_datetime(df['Order Date'])

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])

df = df[pd.to_datetime(df['Order Date']).notna()]

df.groupby(pd.Grouper(freq='D')).mean()
# Out:
# <ipython-input-57-8120455f5385>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['Order Date'] = pd.to_datetime(df['Order Date'])
# <ipython-input-57-8120455f5385>:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(pd.Grouper(freq='D')).mean()
#                  Row ID   Postal Code       Sales
# Date
# 2015-01-02   541.000000  54302.000000  468.900000
# 2015-01-03  6738.800000  70210.200000  220.315100
# 2015-01-04  4664.000000  48371.000000   29.972000
# 2015-01-05          NaN           NaN         NaN
# 2015-01-06  2232.181818  48500.727273  471.683636
# ...                 ...           ...         ...
# ...

# %%
df['Date'] = pd.date_range('2023-01-01', periods=9800)

df.set_index('Order ID', inplace=True)

# %%
df.index
# Out:
# Index(['CA-2017-152156', 'CA-2017-152156', 'CA-2017-138688', 'US-2016-108966',
#        'US-2016-108966', 'CA-2015-115812', 'CA-2015-115812', 'CA-2015-115812',
#        'CA-2015-115812', 'CA-2015-115812',
#        ...
#        'CA-2018-144491', 'CA-2015-127166', 'CA-2015-127166', 'CA-2015-127166',
#        'CA-2015-127166', 'CA-2017-125920', 'CA-2016-128608', 'CA-2016-128608',
#        'CA-2016-128608', 'CA-2016-128608'],
#       dtype='object', name='Order ID', length=9800)

# %%
df.rename(columns={'Order ID': 'Order_ID'}, inplace=True)

# %%
if "Order ID" in df.columns:
    df.drop("Order ID", axis=1, inplace=True)

# %%
# Assuming 'Order Date' is a column in your DataFrame
df['Order Date'] = pd.to_datetime(df['Order Date'])

# %%
resampled_df = df.resample('D', on='Order Date').mean()
# Out:
# <ipython-input-63-708ab7e67fec>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   resampled_df = df.resample('D', on='Order Date').mean()

# %%
df.isnull().sum()
# Out:
# Row ID            0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country           0
# City              0
# State             0
# Postal Code      11
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# LastUpdated       0
# Time              0
# Date              0
# dtype: int64

# %%
df.fillna(method='bfill', inplace=True)

# %%
# data preparation (replace this with your actual data)
monthly_sales = pd.Series(data=[1000, 1200, 1500, 900, 1100, 1300, 1800, 2000],
                          index=pd.date_range(start='2020-01-01', periods=8, freq='M'))

# Plotting the total sales over the 4-year period
plt.figure(figsize=(15, 6))
plt.plot(monthly_sales.index, monthly_sales, label='Total Sales', marker='o')  # You can add a marker for each data point if needed
plt.title('Total Sales Over the 4-Year Period')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.legend()
plt.grid(True)  # You can add a grid if desired
plt.show()

# %% [markdown]
# 7. Seasonal Decomposition

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
# Load the dataset (replace 'path/to/your/IndianCarsDataset.csv' with the actual file path)
df = pd.read_csv('https://raw.githubusercontent.com/Ankit-githb/Winter-Internship-Project---6/main/train.csv')

# %%
# Check the columns in your DataFrame
print(df.columns)

# Assuming the date column is present and named 'Date', change the index
if 'Date' in df.columns:
    df['Date'] = pd.to_datetime(df['Date'])
    df.set_index('Date', inplace=True)
else:
    print("Error: 'Date' column not found in the DataFrame.")

# Display the first few rows of the data
df.head()
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales'],
#       dtype='object')
# Error: 'Date' column not found in the DataFrame.
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# ...

# %%
# Replace the following line with your actual data
# data with a hypothetical time series
time_series_data = pd.Series(np.sin(np.linspace(0, 100, 365)) + np.random.normal(0, 0.1, 365), name='Value')

# Plot the original time series data
plt.figure(figsize=(12, 6))
plt.plot(time_series_data)
plt.title('Original Time Series Data')
plt.show()

# %% [markdown]
# decompose the time series into its components

# %%
# Decompose the time series data into trend, seasonality, and residuals
result = seasonal_decompose(time_series_data, model='additive', period=1)  # You can adjust the period parameter based on the seasonality of your data

# Plot the decomposed components
plt.figure(figsize=(12, 8))

plt.subplot(4, 1, 1)
plt.plot(result.observed)
plt.title('Original Time Series Data')

plt.subplot(4, 1, 2)
plt.plot(result.trend)
plt.title('Trend Component')

plt.subplot(4, 1, 3)
plt.plot(result.seasonal)
plt.title('Seasonal Component')

plt.subplot(4, 1, 4)
plt.plot(result.resid)
plt.title('Residual Component')

plt.tight_layout()
plt.show()

# %% [markdown]
# 8. Box Plots

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load the dataset (replace 'path/to/your/IndianCarsDataset.csv' with the actual file path)
df = pd.read_csv('https://raw.githubusercontent.com/Ankit-githb/Winter-Internship-Project---6/main/train.csv')

# %%
np.random.seed(42)
df = pd.DataFrame({
    'Variable1': np.random.normal(0, 1, 100),
    'Variable2': np.random.normal(0, 1, 100),
})

# %%
#Create box plots
plt.figure(figsize=(10, 6))
sns.boxplot(data=df)
plt.title('Box plots of Numeric Variables')
plt.show()

# %% [markdown]
# 9. Sales Distribution by Category

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load the dataset (replace 'path/to/your/IndianCarsDataset.csv' with the actual file path)
df = pd.read_csv('https://raw.githubusercontent.com/Ankit-githb/Winter-Internship-Project---6/main/train.csv')

# %%
# Sample data (replace this with your actual data)
categories = ['Category A', 'Category B', 'Category C', 'Category D']
sales = [15000, 22000, 18000, 25000]

# %%
# Create a bar chart
plt.figure(figsize=(8, 6))
plt.bar(categories, sales, color='yellowgreen')
plt.title('Distribution of Sales Across Different Categories')
plt.xlabel('Categories')
plt.ylabel('Sales (in dollars)')
plt.show()

# %%
# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(sales, labels=categories, autopct='%1.1f%%', startangle=140, colors=['yellow', 'yellowgreen', 'olivedrab', 'limegreen'])
plt.title('Distribution of Sales Across Different Categories')
plt.show()

# %% [markdown]
# 10. Sales Variation Over Time

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load the dataset (replace 'path/to/your/IndianCarsDataset.csv' with the actual file path)
df = pd.read_csv('https://raw.githubusercontent.com/Ankit-githb/Winter-Internship-Project---6/main/train.csv')

# %%
# Sample data
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
monthly_sales = [10000, 12000, 15000, 11000, 13000, 16000, 18000, 20000, 19000, 22000, 25000, 23000]

quarters = ['Q1', 'Q2', 'Q3', 'Q4']
quarterly_sales = [35000, 48000, 60000, 70000]

years = ['2018', '2019', '2020', '2021', '2022', '2023']
yearly_sales = [180000, 200000, 220000, 250000, 280000, 300000]

# Monthly Sales Line Chart
plt.figure(figsize=(10, 6))
sns.lineplot(x=months, y=monthly_sales, marker='o', color='b')
plt.title('Monthly Sales Variation')
plt.xlabel('Month')
plt.ylabel('Sales ($)')
plt.grid(True)
plt.show()

# Quarterly Sales Line Chart
plt.figure(figsize=(10, 6))
sns.lineplot(x=quarters, y=quarterly_sales, marker='o', color='g')
plt.title('Quarterly Sales Variation')
plt.xlabel('Quarter')
plt.ylabel('Sales ($)')
plt.grid(True)
plt.show()

# Yearly Sales Line Chart
plt.figure(figsize=(10, 6))
sns.lineplot(x=years, y=yearly_sales, marker='o', color='r')
plt.title('Yearly Sales Variation')
plt.xlabel('Year')
plt.ylabel('Sales ($)')
plt.grid(True)
plt.show()
